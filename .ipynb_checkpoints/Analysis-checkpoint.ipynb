# %%
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re

# %%
folder_path = 'runs/test_1/vel_0.1_temp_300'

pos_files = glob.glob(os.path.join(folder_path, '**', 'all*.pos'), recursive=True)

print(pos_files)
# Out:
# ['runs/test_1/vel_0.1_temp_300/all.22300.pos', 'runs/test_1/vel_0.1_temp_300/all.38700.pos', 'runs/test_1/vel_0.1_temp_300/all.400.pos', 'runs/test_1/vel_0.1_temp_300/all.17000.pos', 'runs/test_1/vel_0.1_temp_300/all.5800.pos', 'runs/test_1/vel_0.1_temp_300/all.46800.pos', 'runs/test_1/vel_0.1_temp_300/all.44300.pos', 'runs/test_1/vel_0.1_temp_300/all.43500.pos', 'runs/test_1/vel_0.1_temp_300/all.30500.pos', 'runs/test_1/vel_0.1_temp_300/all.50400.pos', 'runs/test_1/vel_0.1_temp_300/all.12700.pos', 'runs/test_1/vel_0.1_temp_300/all.35000.pos', 'runs/test_1/vel_0.1_temp_300/all.52100.pos', 'runs/test_1/vel_0.1_temp_300/all.2100.pos', 'runs/test_1/vel_0.1_temp_300/all.4400.pos', 'runs/test_1/vel_0.1_temp_300/all.42900.pos', 'runs/test_1/vel_0.1_temp_300/all.50900.pos', 'runs/test_1/vel_0.1_temp_300/all.9500.pos', 'runs/test_1/vel_0.1_temp_300/all.43600.pos', 'runs/test_1/vel_0.1_temp_300/all.39100.pos', 'runs/test_1/vel_0.1_temp_300/all.30800.pos', 'runs/test_1/vel_0.1_temp_300/all.38000.pos', 'runs/test_1/vel_0.1_temp_300/all.52300.pos', 'runs/test_1/vel_0.1_temp_300/all.48600.pos', 'runs/test_1/vel_0.1_temp_300/all.20500.pos', 'runs/test_1/vel_0.1_temp_300/all.47700.pos', 'runs/test_1/vel_0.1_temp_300/all.23500.pos', 'runs/test_1/vel_0.1_temp_300/all.2900.pos', 'runs/test_1/vel_0.1_temp_300/all.29900.pos', 'runs/test_1/vel_0.1_temp_300/all.13100.pos', 'runs/test_1/vel_0.1_temp_300/all.40000.pos', 'runs/test_1/vel_0.1_temp_300/all.31300.pos', 'runs/test_1/vel_0.1_temp_300/all.31000.pos', 'runs/test_1/vel_0.1_temp_300/all.16100.pos', 'runs/test_1/vel_0.1_temp_300/all.50000.pos', 'runs/test_1/vel_0.1_temp_300/all.35800.pos', 'runs/test_1/vel_0.1_temp_300/all.3000.pos', 'runs/test_1/vel_0.1_temp_300/all.20200.pos', 'runs/test_1/vel_0.1_temp_300/all.28300.pos', 'runs/test_1/vel_0.1_temp_300/all.26500.pos', 'runs/test_1/vel_0.1_temp_300/all.48400.pos', 'runs/test_1/vel_0.1_temp_300/all.40400.pos', 'runs/test_1/vel_0.1_temp_300/all.49900.pos', 'runs/test_1/vel_0.1_temp_300/all.26000.pos', 'runs/test_1/vel_0.1_temp_300/all.40100.pos', 'runs/test_1/vel_0.1_temp_300/all.12100.pos', 'runs/test_1/vel_0.1_temp_300/all.18000.pos', 'runs/test_1/vel_0.1_temp_300/all.20300.pos', 'runs/test_1/vel_0.1_temp_300/all.24300.pos', 'runs/test_1/vel_0.1_temp_300/all.4700.pos', 'runs/test_1/vel_0.1_temp_300/all.6600.pos', 'runs/test_1/vel_0.1_temp_300/all.52600.pos', 'runs/test_1/vel_0.1_temp_300/all.22700.pos', 'runs/test_1/vel_0.1_temp_300/all.22000.pos', 'runs/test_1/vel_0.1_temp_300/all.15200.pos', 'runs/test_1/vel_0.1_temp_300/all.8300.pos', 'runs/test_1/vel_0.1_temp_300/all.51700.pos', 'runs/test_1/vel_0.1_temp_300/all.49200.pos', 'runs/test_1/vel_0.1_temp_300/all.33400.pos', 'runs/test_1/vel_0.1_temp_300/all.22600.pos', 'runs/test_1/vel_0.1_temp_300/all.51200.pos', 'runs/test_1/vel_0.1_temp_300/all.26200.pos', 'runs/test_1/vel_0.1_temp_300/all.5500.pos', 'runs/test_1/vel_0.1_temp_300/all.27800.pos', 'runs/test_1/vel_0.1_temp_300/all.18500.pos', 'runs/test_1/vel_0.1_temp_300/all.49400.pos', 'runs/test_1/vel_0.1_temp_300/all.23900.pos', 'runs/test_1/vel_0.1_temp_300/all.17600.pos', 'runs/test_1/vel_0.1_temp_300/all.13200.pos', 'runs/test_1/vel_0.1_temp_300/all.7400.pos', 'runs/test_1/vel_0.1_temp_300/all.16000.pos', 'runs/test_1/vel_0.1_temp_300/all.7700.pos', 'runs/test_1/vel_0.1_temp_300/all.1100.pos', 'runs/test_1/vel_0.1_temp_300/all.9000.pos', 'runs/test_1/vel_0.1_temp_300/all.43800.pos', 'runs/test_1/vel_0.1_temp_300/all.20000.pos', 'runs/test_1/vel_0.1_temp_300/all.41600.pos', 'runs/test_1/vel_0.1_temp_300/all.12000.pos', 'runs/test_1/vel_0.1_temp_300/all.13300.pos', 'runs/test_1/vel_0.1_temp_300/all.28800.pos', 'runs/test_1/vel_0.1_temp_300/all.7000.pos', 'runs/test_1/vel_0.1_temp_300/all.19300.pos', 'runs/test_1/vel_0.1_temp_300/all.27000.pos', 'runs/test_1/vel_0.1_temp_300/all.7200.pos', 'runs/test_1/vel_0.1_temp_300/all.48000.pos', 'runs/test_1/vel_0.1_temp_300/all.4100.pos', 'runs/test_1/vel_0.1_temp_300/all.39400.pos', 'runs/test_1/vel ...

# %%
def count_data(filepath):
    coordinates = []

    with open(filepath, 'r') as file:
        lines = file.readlines()
        for line in lines:
            if line.startswith("ITEM: TIMESTEP"):
                timestep = int(lines[lines.index(line) + 1].strip())
            if line.startswith("ITEM: ATOMS"):
                line_atom = line
                break

        for line in lines[lines.index(line_atom)+1:]:
            if line.strip():
                parts = line.split()
                if len(parts) >= 5:
                    x = float(parts[2])
                    y = float(parts[3])
                    z = float(parts[4])
                    vx = float(parts[5])
                    vy = float(parts[6])
                    vz = float(parts[7])
                    if len(parts) >=9:
                        c = float(parts[8])
                    else:
                        c = -1
                    coordinates.append([x, y, z, vx, vy, vz, c])
                    

    coordinates = np.array(coordinates)

    mean_coordinates = np.mean(coordinates, axis=0)

    #print(f"Timestep: {timestep}")
    #print(f"Средние координаты атомов (x, y, z): {mean_coordinates}"
    
    return np.append(mean_coordinates, timestep)

# %%
filename = 'all.' + str(0) + '.pos'

count_data(filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 3
#       1 filename = 'all.' + str(0) + '.pos'
# ----> 3 count_data(filename)
#
# Cell In[18], line 4, in count_data(filepath)
#       1 def count_data(filepath):
#       2     coordinates = []
# ----> 4     with open(filepath, 'r') as file:
#       5         lines = file.readlines()
#       6         for line in lines:
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'all.0.pos'

# %%
data = []

for filepath in pos_files:
    data.append(count_data(filepath))

# %%
df = pd.DataFrame(data, columns=['x', 'y', 'z', 'vx', 'vy', 'vz', 'c', 'Step'])

# %%
df = df.sort_values(by='Step')
df
# Out:
#             x             y          z        vx        vy        vz    c  \
# 377 -0.000004 -4.727273e-07  18.174634  0.000000  0.000000  0.000000 -1.0
# 175  0.000673  7.980606e-05  18.165214  0.000000  0.000000  0.000000 -1.0
# 343  0.000457  4.985152e-05  18.155083  0.000000  0.000000  0.000000 -1.0
# 252  0.000289  2.607576e-05  18.151819  0.000000  0.000000  0.000000 -1.0
# 2    0.000136  8.912121e-06  18.153755  0.000000  0.000000  0.000000 -1.0
# ..        ...           ...        ...       ...       ...       ...  ...
# 323  0.617692 -1.313258e-01  23.022047  0.000970  0.001039  0.001394 -1.0
# 515  0.618646 -1.302832e-01  23.023440  0.000937  0.001047  0.001388 -1.0
# 372  0.619566 -1.292311e-01  23.024825  0.000901  0.001058  0.001384 -1.0
# 494  0.620445 -1.281662e-01  23.026206  0.000856  0.001072  0.001378 -1.0
# 275  0.621279 -1.270880e-01  23.027582  0.000810  0.001084  0.001372 -1.0
#
#         Step
# 377      0.0
# 175    100.0
# 343    200.0
# 252    300.0
# 2      400.0
# ..       ...
# 323  53100.0
# 515  53200.0
# 372  53300.0
# 494  53400.0
# 275  53500.0
#
# [537 rows x 8 columns]

# %%
plt.figure(figsize=(12, 8))

plt.subplot(3, 1, 1)
plt.plot(df.Step, df.x, label='x', color='r')
plt.xlabel('Timestep')
plt.ylabel('x')
plt.title('Координаты x от времени')
plt.grid(True)

plt.subplot(3, 1, 2)
plt.plot(df.Step, df.y, label='y', color='g')
plt.xlabel('Timestep')
plt.ylabel('y')
plt.title('Координаты y от времени')
plt.grid(True)

plt.subplot(3, 1, 3)
plt.plot(df.Step, df.z, label='z', color='b')
plt.xlabel('Timestep')
plt.ylabel('z')
plt.title('Координаты z от времени')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 plt.figure(figsize=(12, 8))
#       3 plt.subplot(3, 1, 1)
# ----> 4 plt.plot(df.Step, df.x, label='x', color='r')
#       5 plt.xlabel('Timestep')
#       6 plt.ylabel('x')
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(12, 8))

plt.subplot(3, 1, 1)
plt.plot(df.Step, df.vx, label='x', color='r')
plt.xlabel('Timestep')
plt.ylabel('x')
plt.title('Скорость x от времени')
plt.grid(True)

plt.subplot(3, 1, 2)
plt.plot(df.Step, df.vy, label='y', color='g')
plt.xlabel('Timestep')
plt.ylabel('y')
plt.title('Скорость y от времени')
plt.grid(True)

plt.subplot(3, 1, 3)
plt.plot(df.Step, df.vz, label='z', color='b')
plt.xlabel('Timestep')
plt.ylabel('z')
plt.title('Скорость z от времени')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 plt.figure(figsize=(12, 8))
#       3 plt.subplot(3, 1, 1)
# ----> 4 plt.plot(df.Step, df.vx, label='x', color='r')
#       5 plt.xlabel('Timestep')
#       6 plt.ylabel('x')
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(12, 8))

plt.plot(df.Step, df.c, label='x', color='r')
plt.xlabel('Timestep')
plt.ylabel('c')
plt.title('Среднее количесвто связей')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import re
import pandas as pd

def extract_lammps_data(log_file):
    with open(log_file, 'r') as file:
        log_data = file.read()

    pattern = r"\s*(\d+)\s+([\d\.]+)\s+([\d\.-]+)\s+([\d\.-]+)\s+([\d\.-]+)\s+([\d\.-]+)\s+([\d\.-]+)\s+([\d\.-]+)"

    matches = re.findall(pattern, log_data, re.MULTILINE)

    if matches:
        data = pd.DataFrame(matches, columns=['Step', 'Time', 'Temp', 'PotEng', 'KinEng', 'TotEng', 'Press', 'Volume'])
        
        data = data.apply(pd.to_numeric, errors='ignore')
        
        data = data.sort_values(by='Step')

        return data
    else:
        print("Совпадения не найдены.")
        return None

log_file = 'log.lammps' 
data = extract_lammps_data(log_file)



data
# Out:
#      Step    Time       Temp     PotEng     KinEng      TotEng       Press  \
# 0       0     0.0       0.00 -189585.77        0.0  -189585.77  -21.017154
# 155     1     0.0       0.00       0.00        0.0        0.00           0
# 154     1     0.0       0.00       0.00        0.0        0.00           0
# 156     1     0.0       0.00       0.00        0.0        0.00           0
# 51      1     0.0       0.00       0.00        0.0        0.00           0
# ..    ...     ...        ...        ...        ...         ...         ...
# 114  9100  1493.6  569229.17 -182708.48  1932614.2  1749905.80   201824.85
# 115  9200  1498.6  570274.58 -183982.23  1936163.5  1752181.30   202014.12
# 116  9300  1503.6  570312.08 -184155.15  1936290.9  1752135.70   202015.35
# 117  9400  1508.6  570321.10 -184184.61  1936321.5  1752136.90   202141.27
# 118  9500  1513.6  570328.14 -184207.10  1936345.4  1752138.30   202094.41
#
#         Volume
# 0    435330.70
# 155       0.00
# 154       0.00
# 156       0.00
# 51        0.00
# ..         ...
# 114  436617.21
# 115  436617.21
# 116  436617.21
# 117  436617.21
# 118      17.21
#
# [158 rows x 8 columns]

# %%
plt.figure(figsize=(12, 8))

plt.scatter(data.Time[data.Time>0], data.PotEng[data.Time>0], label='x', color='r')
plt.xlabel('Time')
plt.ylabel('PotEng')
#plt.title('Среднее количесвто связей')
plt.grid(True)

plt.tight_layout()
plt.show()
